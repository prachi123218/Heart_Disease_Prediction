# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/ADMIN/Heart_Disease_Prediction/Data/disease_prediction.csv")

# %%
data
# Out:
#      patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 0             1   32    Male            101                235          152
# 1             2   31    Male            124                191          134
# 2             3   45    Male             57                141          114
# 3             4   75  Female             69                268          120
# 4             5   53    Male            107                163          131
# ..          ...  ...     ...            ...                ...          ...
# 995         996   24    Male            105                237           86
# 996         997   40    Male            120                219          133
# 997         998   44  Female            114                273          114
# 998         999   31    Male             95                231          130
# 999        1000   83    Male            109                256          103
#
# ...

# %% [markdown]
# Performing Data Analysis

# %%
data.head()
# Out:
#    patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 0           1   32    Male            101                235          152
# 1           2   31    Male            124                191          134
# 2           3   45    Male             57                141          114
# 3           4   75  Female             69                268          120
# 4           5   53    Male            107                163          131
#
#    diastolic_bp   bmi  heart_rate smoking alcohol_consumption  \
# 0            79  28.5          73      No                 Yes
# 1            77  33.9          71      No                 Yes
# 2            71  27.2          79     Yes                 Yes
# 3            82  21.5          61     Yes                 Yes
# 4            75  23.3          73     Yes                  No
#
#   physical_activity family_history disease
# 0               Low            Yes     Yes
# 1               Low            Yes     Yes
# ...

# %%
data.tail()
# Out:
#      patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 995         996   24    Male            105                237           86
# 996         997   40    Male            120                219          133
# 997         998   44  Female            114                273          114
# 998         999   31    Male             95                231          130
# 999        1000   83    Male            109                256          103
#
#      diastolic_bp   bmi  heart_rate smoking alcohol_consumption  \
# 995            86  30.9          69     Yes                 Yes
# 996            72  34.3          92     Yes                 Yes
# 997            74  36.0          76      No                  No
# 998            72  28.2          81     Yes                 Yes
# 999            86  30.3          64     Yes                 Yes
#
#     physical_activity family_history disease
# 995            Medium             No      No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           1000 non-null   int64
#  1   age                  1000 non-null   int64
#  2   gender               1000 non-null   object
#  3   glucose_mg_dl        1000 non-null   int64
#  4   cholesterol_mg_dl    1000 non-null   int64
#  5   systolic_bp          1000 non-null   int64
#  6   diastolic_bp         1000 non-null   int64
#  7   bmi                  1000 non-null   float64
#  8   heart_rate           1000 non-null   int64
#  9   smoking              1000 non-null   object
#  10  alcohol_consumption  1000 non-null   object
#  11  physical_activity    1000 non-null   object
#  12  family_history       1000 non-null   object
#  13  disease              1000 non-null   object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 109.5+ KB

# %%
data.describe()
# Out:
#         patient_id          age  glucose_mg_dl  cholesterol_mg_dl  \
# count  1000.000000  1000.000000    1000.000000        1000.000000
# mean    500.500000    51.190000     104.163000         210.014000
# std     288.819436    19.847514      25.076508          39.749111
# min       1.000000    18.000000      30.000000          89.000000
# 25%     250.750000    33.000000      87.000000         183.000000
# 50%     500.500000    52.500000     105.000000         210.500000
# 75%     750.250000    69.000000     121.000000         235.250000
# max    1000.000000    85.000000     184.000000         339.000000
#
#        systolic_bp  diastolic_bp          bmi   heart_rate
# count  1000.000000   1000.000000  1000.000000  1000.000000
# mean    123.893000     81.032000    26.093000    75.968000
# std      18.701211      9.969974     4.758282     9.902982
# min      67.000000     49.000000    16.000000    47.000000
# 25%     111.000000     74.000000    22.900000    70.000000
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.size
# Out:
# 14000

# %%
data.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'glucose_mg_dl', 'cholesterol_mg_dl',
#        'systolic_bp', 'diastolic_bp', 'bmi', 'heart_rate', 'smoking',
#        'alcohol_consumption', 'physical_activity', 'family_history',
#        'disease'],
#       dtype='object')

# %% [markdown]
# Checking Outlier

# %%
print(f"Min Age = {data['age'].min()}")
print(f"Max Age = {data['age'].max()}")
# Out:
# Min Age = 18
# Max Age = 85

# %%
print(f"Min Glucose(mg/dl) = {data['glucose_mg_dl'].min()}")
print(f"Max Glucose(mg/dl) = {data['glucose_mg_dl'].max()}")
# Out:
# Min Glucose(mg/dl) = 30
# Max Glucose(mg/dl) = 184

# %%
print(f"Min Cholesterol(mg/dl) = {data['cholesterol_mg_dl'].min()}")
print(f"Max Cholesterol(mg/dl) = {data['cholesterol_mg_dl'].max()}")
# Out:
# Min Cholesterol(mg/dl) = 89
# Max Cholesterol(mg/dl) = 339

# %%
print(f"Min Systolic BP = {data['systolic_bp'].min()}")
print(f"Max Systolic BP = {data['systolic_bp'].max()}")
# Out:
# Min Systolic BP = 67
# Max Systolic BP = 195

# %%
print(f"Min Diastolic BP = {data['diastolic_bp'].min()}")
print(f"Max Diastolic BP = {data['diastolic_bp'].max()}")
# Out:
# Min Diastolic BP = 49
# Max Diastolic BP = 113

# %%
print(f"Min BMI = {data['bmi'].min()}")
print(f"Max BMI = {data['bmi'].max()}")
# Out:
# Min BMI = 16.0
# Max BMI = 41.5

# %%
print(f"Min Heart Rate = {data['heart_rate'].min()}")
print(f"Max Heart Rate = {data['heart_rate'].max()}")
# Out:
# Min Heart Rate = 47
# Max Heart Rate = 114

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.isnull().sum()
# Out:
# patient_id             0
# age                    0
# gender                 0
# glucose_mg_dl          0
# cholesterol_mg_dl      0
# systolic_bp            0
# diastolic_bp           0
# bmi                    0
# heart_rate             0
# smoking                0
# alcohol_consumption    0
# physical_activity      0
# family_history         0
# disease                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#Disease Distribution
data['disease'].value_counts().plot(kind='bar')

plt.title("Disease Distribution")
plt.xlabel("Disease")
plt.ylabel("Count")

plt.show()

# %%
sns.countplot(x='family_history', hue='disease', data=data)
plt.show()

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['gender', 'smoking', 'alcohol_consumption', 'physical_activity',
#        'family_history', 'disease'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in ['gender', 'smoking', 'alcohol_consumption',
            'physical_activity', 'family_history', 'disease']:
    
    data[col] = le.fit_transform(data[col])

# %%
data[col]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 995    0
# 996    0
# 997    1
# 998    0
# 999    1
# Name: disease, Length: 1000, dtype: int32

# %%
data['gender']
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: gender, Length: 1000, dtype: int32

# %%
data['physical_activity']
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      1
#       ..
# 995    2
# 996    2
# 997    1
# 998    2
# 999    0
# Name: physical_activity, Length: 1000, dtype: int32

# %%
#Univariate Analysis

# %%
data['age'].hist()
plt.show()

# %%
sns.boxplot(x=data['cholesterol_mg_dl'])
plt.show()

# %%
sns.countplot(x='smoking', data=data)
plt.show()

# %%
#Bivarient Analysis

# %%
sns.boxplot(x='disease', y='cholesterol_mg_dl', data=data)
plt.show()

# %%
sns.countplot(x='smoking', hue='disease', data=data)
plt.show()

# %%
corr = data.corr(numeric_only=True)

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(data, hue='disease')
plt.show()

# %%
data['disease'].value_counts(normalize=True)
# Out:
# disease
# 1    0.501
# 0    0.499
# Name: proportion, dtype: float64

# %%
data[data['glucose_mg_dl'] == 30]
# Out:
#      patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 491         492   25       1             30                202           95
#
#      diastolic_bp   bmi  heart_rate  smoking  alcohol_consumption  \
# 491            94  26.4          83        0                    1
#
#      physical_activity  family_history  disease
# 491                  1               1        0

# %%
data = data[data['glucose_mg_dl'] != 30]

# %%
data[data['glucose_mg_dl'] == 30]
# Out:
# Empty DataFrame
# Columns: [patient_id, age, gender, glucose_mg_dl, cholesterol_mg_dl, systolic_bp, diastolic_bp, bmi, heart_rate, smoking, alcohol_consumption, physical_activity, family_history, disease]
# Index: []
